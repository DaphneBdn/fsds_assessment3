# %% [markdown]
# # Front Matter: CASA0013: Foundations of Spatial Data Science
#
# ## Title of Briefing
#
# ### Student ID
#
# ### Word Count:

# %% [markdown]
# # Reproducible Analysis
#
# Please feel free to add as many code cells and markdown cells of comment/explanation as needed to make your code legible and clear. Your code should output any figures needed to disk.

# %% [markdown]
# ## Classification of Airbnb penetration in London

# %% [markdown]
# This notebook holds the analysis for the classification of Airbnb penetration in London.
# After a first exploration of the datasets with visualisations that seek to quantify the current picture of Airbnb listings in London, the London wards are classified by their amaount of listings (low, medium, large), followed by a geodemographic classification of the neighboorhods that attempts to identify patterns expaining and perhaps predicting the presence or absense of listings.

# %% [markdown]
# Data used for this analysis were obtained from the following sources:
# * Airbnb listings, compiled 10 October 2021: <http://insideairbnb.com/get-the-data.html>
# * London Wards data: <https://data.london.gov.uk/dataset/ward-profiles-and-atlas>
# * London Wards geography: <https://data.london.gov.uk/dataset/statistical-gis-boundary-files-london>
#
# For ease of access the data has been saved in the following github repository: <https://github.com/DaphneBdn/fsds_cw3>

# %% [markdown]
# ### Libraries

# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data import

# %% [markdown]
# Airbnb Data

# %%
#saved in github repo!
# load files from link 
# make public

# %%
dataloc = os.path.join('Data','raw','listings.csv.gz')
print(dataloc)
# Out:
# Data/raw/listings.csv.gz

# %%
df = pd.read_csv(dataloc, compression='gzip', low_memory=False)
#df.head()
print(f"Data frame is {df.shape[0]:,} x {df.shape[1]}")
# Out:
# Data frame is 67,903 x 74

# %%
# check the dataframe by printing a sample
df.sample(5, random_state=42)
# Out:
#              id                            listing_url       scrape_id  \
# 53662  42409608  https://www.airbnb.com/rooms/42409608  20211010233627
# 49155  39318693  https://www.airbnb.com/rooms/39318693  20211010233627
# 36922  29555250  https://www.airbnb.com/rooms/29555250  20211010233627
# 22088  19248360  https://www.airbnb.com/rooms/19248360  20211010233627
# 13505  13104327  https://www.airbnb.com/rooms/13104327  20211010233627
#
#       last_scraped                                               name  \
# 53662   2021-10-11            Cosy two bedroom home full of character
# 49155   2021-10-11      Frills-free yet Clean and Comfortable Bedroom
# 36922   2021-10-12  Unmissable Luxurious Mews House in Central London
# 22088   2021-10-11           Wonderful Private room+tea/coffee&sweets
# 13505   2021-10-12          Spacious 2 bed apartment in Little Venice
#
#                                              description  \
# 53662  Cosy and welcoming flat on a quiet safe reside...
# 49155  • Frills-free yet very convenient, clean, quie...
# 36922  This breathtaking elegant 2 bedroom house is l...
# 22088  A beautiful private room in Stratford, excelle...
# 13505  With a modern kitchen area, high spec bathroom...
#
#                                    neighborhood_overview  \
# 53662  Famous All England Tennis Club 20 minute walk ...
# 49155  2 minutes' walk to the "legendary" Brick Lane....
# 36922  Belgravia is one of the most prestigious and u...
# 22088                                                NaN
# 13505  Little Venice may be London’s best kept secret...
#
#                                              picture_url    host_id  \
# 53662  https://a0.muscache.com/pictures/bf1d0be2-102a...  153634672
# 49155  https://a0.muscache.com/pictures/460a0011-9524...  301890899
# 36922  https://a0.muscache.com/pictures/f8b371f5-14dc...   27572615
# 22088  https://a0.muscache.com/pictures/b68ceecc-db45...  132839496
# 13505  https://a0.muscache.com/pictures/b7216178-f1c1...   33889201
#
#                                           host_url  ...  \
# 53662  https://www.airbnb.com/users/show/153634672  ...
# 49155  https://www.airbnb.com/users/show/301890899  ...
# 36922   https://www.airbnb.com/users/show/27572615  ...
# 22088  https://www.airbnb.com/users/show/132839496  ...
# 13505   https://www.airbnb.com/users/show/33889201  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 53662                         NaN                    NaN                 NaN
# 49155                         5.0                   5.00                4.00
# 36922                         5.0                   5.00                4.50
# 22088                         4.4                   3.95                4.53
# 13505                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 53662     NaN                t                              1
# 49155     NaN                f                              1
# 36922     NaN                f                            131
# 22088     NaN                t                              5
# 13505     NaN                t                            857
#
#       calculated_host_listings_count_entire_homes  \
# 53662                                           1
# 49155                                           0
# 36922                                         131
# 22088                                           0
# 13505                                         856
#
#       calculated_host_listings_count_private_rooms  \
# 53662                                            0
# 49155                                            1
# 36922                                            0
# 22088                                            5
# 13505                                            1
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 53662                                           0               NaN
# 49155                                           0              0.08
# 36922                                           0              0.06
# 22088                                           0              0.38
# 13505                                           0               NaN
#
# [5 rows x 74 columns]

# %%
# extract the column names
cols=df.columns
print(cols)
print(f"The Inside Airbnb dataset has {len(cols)} columns/variables")
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')
# The Inside Airbnb dataset has 74 columns/variables

# %% [markdown]
# ### Investigate NA values

# %%
# change settings to display all rows
pd.set_option('display.max_rows', None)
# print out the count of NA values per column
df.isna().sum().sort_values(ascending=False)
# Out:
# neighbourhood_group_cleansed                    67903
# calendar_updated                                67903
# license                                         67903
# bathrooms                                       67903
# host_response_rate                              34288
# host_response_time                              34288
# host_acceptance_rate                            33907
# host_about                                      30360
# neighborhood_overview                           26939
# neighbourhood                                   26938
# review_scores_value                             20472
# review_scores_location                          20468
# review_scores_checkin                           20467
# review_scores_communication                     20430
# review_scores_accuracy                          20427
# review_scores_cleanliness                       20415
# first_review                                    19028
# reviews_per_month                               19028
# last_review                                     19028
# review_scores_rating                            19028
# host_neighbourhood                              18997
# bedrooms                                         4258
# description                                      2515
# beds                                              847
# bathrooms_text                                    188
# host_location                                     181
# host_has_profile_pic                               32
# host_name                                          32
# host_is_superhost                                  32
# host_total_listings_count                          32
# host_since                                         32
# host_identity_verified                             32
# host_thumbnail_url                                 32
# host_listings_count                                32
# host_picture_url                                   32
# name                                               24
# maximum_maximum_nights                              3
# minimum_maximum_nights                              3
# maximum_nights_avg_ntm                              3
# minimum_nights_avg_ntm                              3
# maximum_minimum_nights                              3
# minimum_minimum_nights                              3
# number_of_reviews_l30d                              0
# host_id                                             0
# host_url                                            0
# number_of_reviews                                   0
# picture_url                                         0
# last_scraped                                        0
# scrape_id                                           0
# instant_bookable                                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# number_of_reviews_ltm                               0
# has_availability                                    0
# calendar_last_scraped                               0
# availability_365                                    0
# host_verifications                                  0
# neighbourhood_cleansed                              0
# latitude                                            0
# longitude                                           0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# listing_url                                         0
# amenities                                           0
# price                                               0
# minimum_nights                                      0
# maximum_nights                                      0
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# id                                                  0
# dtype: int64

# %%
# change settings back 
pd.reset_option('all')
# Out:
# As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/_config/config.py:630: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#   warnings.warn(d.msg, FutureWarning)
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/_config/config.py:630: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)

# %%
print(cols)
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
 sub_cols=['id', 'name',
       'host_id', 
       'host_name', 'host_since', 'host_location', 'host_about',
       'host_is_superhost', 
       'host_neighbourhood', 
       'host_total_listings_count',  
       'neighbourhood_cleansed',
       'latitude','longitude', 'property_type', 'room_type', 'accommodates',
       'bedrooms', 'price',
       'availability_30', 'availability_60', 'availability_90',
       'availability_365', 'number_of_reviews', 'number_of_reviews_l30d', 'first_review',
       'last_review', 'review_scores_rating']

# %%
sub_cols=['id', 'name',
       'latitude','longitude', 'property_type', 'room_type', 'price',
       'availability_365', 'number_of_reviews_l30d', 'first_review',
       'last_review']

# %%
df= df[sub_cols]
df.set_index('id', inplace=True)
df.head()
# Out:
#                                                     name  latitude  longitude  \
# id
# 13913                Holiday London DB Room Let-on going  51.56861   -0.11270
# 15400                Bright Chelsea  Apartment. Chelsea!  51.48780   -0.16813
# 17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1  51.52195   -0.14094
# 17506  Boutique Chelsea/Fulham Double bed 5-star ensuite  51.47935   -0.19743
# 24328  Battersea bedroom & studio, parking, shared ga...  51.47119   -0.16256
#
#                      property_type        room_type    price  \
# id
# 13913  Private room in rental unit     Private room   $65.00
# 15400           Entire rental unit  Entire home/apt   $75.00
# 17402           Entire rental unit  Entire home/apt  $307.00
# 17506    Private room in townhouse     Private room  $150.00
# 24328             Entire townhouse  Entire home/apt  $200.00
#
#        availability_365  number_of_reviews_l30d first_review last_review
# id
# 13913               339                       0   2011-07-11  2011-09-13
# 15400                 2                       0   2012-07-16  2019-08-10
# 17402               320                       0   2011-09-18  2019-11-02
# 17506               364                       0          NaN         NaN
# 24328               273                       0   2011-11-01  2015-10-24

# %%
# use pandas function replace to replace $ and comma eg $1,000

df["price"]=df.price.str.replace('$','').str.replace(',','').astype('float')
df.head()
# Out:
# /tmp/ipykernel_2263/2720214001.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["price"]=df.price.str.replace('$','').str.replace(',','').astype('float')
#                                                     name  latitude  longitude  \
# id
# 13913                Holiday London DB Room Let-on going  51.56861   -0.11270
# 15400                Bright Chelsea  Apartment. Chelsea!  51.48780   -0.16813
# 17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1  51.52195   -0.14094
# 17506  Boutique Chelsea/Fulham Double bed 5-star ensuite  51.47935   -0.19743
# 24328  Battersea bedroom & studio, parking, shared ga...  51.47119   -0.16256
#
#                      property_type        room_type  price  availability_365  \
# id
# 13913  Private room in rental unit     Private room   65.0               339
# 15400           Entire rental unit  Entire home/apt   75.0                 2
# 17402           Entire rental unit  Entire home/apt  307.0               320
# 17506    Private room in townhouse     Private room  150.0               364
# 24328             Entire townhouse  Entire home/apt  200.0               273
#
#        number_of_reviews_l30d first_review last_review
# id
# 13913                       0   2011-07-11  2011-09-13
# 15400                       0   2012-07-16  2019-08-10
# 17402                       0   2011-09-18  2019-11-02
# 17506                       0          NaN         NaN
# 24328                       0   2011-11-01  2015-10-24

# %% [markdown]
# Convert the dataframe(df) into a geodataframe using the epsg code for the World Geodetic System 1984, then convert to British National Grid

# %%
gdf = gpd.GeoDataFrame(df, 
                       geometry=gpd.points_from_xy(df.longitude, df.latitude, 
                       crs= 'epsg:4326'))
gdf = gdf.to_crs('epsg:27700')

# %%
#check the geodataframe
gdf.plot(column="price")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### London Spatial Units (wards)

# %%
dataloc_geo = os.path.join("Data","raw", "statistical-gis-boundaries-london","ESRI", "London_Ward_CityMerged.shp")
print(dataloc_geo)
# Out:
# Data/raw/statistical-gis-boundaries-london/ESRI/London_Ward_CityMerged.shp

# %%
wards = gpd.read_file( dataloc_geo )
wards.plot()

# add river!!
# Out:
# <AxesSubplot:>

# %%
wards = wards.to_crs('epsg:27700')

# %%
wards.describe()
# Out:
#           HECTARES  NONLD_AREA        POLY_ID
# count   625.000000  625.000000     625.000000
# mean    255.151568    3.390584   84914.571200
# std     258.004032   15.606775   33172.213229
# min      39.212000    0.000000   50449.000000
# 25%     123.197000    0.000000   50901.000000
# 50%     186.610000    0.000000  116701.000000
# 75%     289.774000    0.000000  117136.000000
# max    2903.960000  154.284000  123573.000000

# %% [markdown]
# ### London Boundary

# %% [markdown]
# create the boundary of London for maps

# %%
boros = gpd.read_file('https://github.com/jreades/i2p/blob/master/data/src/Boroughs.gpkg?raw=true')
boros.plot()
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/geopandas/geodataframe.py:577: RuntimeWarning: Sequential read of iterator was interrupted. Resetting iterator. This can negatively impact the performance.
#   for feature in features_lst:
# <AxesSubplot:>

# %%
ldn = gpd.GeoDataFrame(gpd.GeoSeries(data=boros.unary_union, crs='epsg:27700')).rename(columns={0:'original'})

# %%
ldn['geometry'] = ldn.original.buffer(20)
ldn = ldn.set_geometry('geometry')
ldn.plot();

# %% [markdown]
# --------

# %%
## Data exploration and summary statistics

# %% [markdown]
# ### Join data

# %% [markdown]
# Join the listings with the shapefile

# %%
gdf.sample(3)
# Out:
#                                                        name  latitude  \
# id
# 50588229   Spacious and Newly Built 1BR Flat in West London  51.50198
# 5688653                      SUNNY DOUBLE BEDROOM IN BALHAM  51.44107
# 20757007  Sunny room in newly refurbished south London flat  51.40014
#
#           longitude                property_type        room_type  price  \
# id
# 50588229   -0.24406   Entire condominium (condo)  Entire home/apt  100.0
# 5688653    -0.16029  Private room in rental unit     Private room   44.0
# 20757007   -0.08580  Private room in rental unit     Private room   25.0
#
#           availability_365  number_of_reviews_l30d first_review last_review  \
# id
# 50588229               111                       0          NaN         NaN
# 5688653                  0                       0          NaN         NaN
# 20757007                54                       0   2017-10-05  2019-12-02
#
#                                geometry
# id
# 50588229  POINT (521975.259 179577.394)
# 5688653   POINT (527959.414 172946.804)
# 20757007  POINT (533255.068 168527.972)

# %%
wards.sample(3)
# Out:
#             NAME   GSS_CODE  HECTARES  NONLD_AREA  LB_GSS_CD  \
# 55   Copers Cope  E05000113   328.692         0.0  E09000006
# 22   Sanderstead  E05000160   634.600         0.0  E09000008
# 399      Whitton  E05000533   162.597         0.0  E09000027
#
#                   BOROUGH  POLY_ID  \
# 55                Bromley   117279
# 22                Croydon    50899
# 399  Richmond upon Thames    51142
#
#                                               geometry
# 55   POLYGON ((536723.100 170334.000, 536722.800 17...
# 22   POLYGON ((535009.200 159504.700, 535005.500 15...
# 399  POLYGON ((515020.300 173404.700, 515000.100 17...

# %%
gdf_wards = gpd.sjoin(gdf, wards, how='left', op='within')
print(gdf_wards.columns.values)
# Out:
# ['name' 'latitude' 'longitude' 'property_type' 'room_type' 'price'
#  'availability_365' 'number_of_reviews_l30d' 'first_review' 'last_review'
#  'geometry' 'index_right' 'NAME' 'GSS_CODE' 'HECTARES' 'NONLD_AREA'
#  'LB_GSS_CD' 'BOROUGH' 'POLY_ID']

# %%
gdf_wards.sample(3)
# Out:
#                                                    name  latitude  longitude  \
# id
# 6524562                     Urban Oasis in Canary Wharf  51.49734   -0.01219
# 21719580                               Carlyle House -1  51.55375    0.04818
# 18817908  Stylish period Fulham home, South West London  51.48323   -0.22123
#
#                              property_type        room_type  price  \
# id
# 6524562        Private room in rental unit     Private room   23.0
# 21719580  Private room in residential home     Private room   22.0
# 18817908           Entire residential home  Entire home/apt  126.0
#
#           availability_365  number_of_reviews_l30d first_review last_review  \
# id
# 6524562                  0                       0          NaN         NaN
# 21719580               131                       0   2018-08-23  2018-08-28
# 18817908                 0                       0   2017-07-10  2018-10-10
#
#                                geometry  index_right  \
# id
# 6524562   POINT (538081.851 179472.973)        517.0
# 21719580  POINT (542096.479 185861.354)        605.0
# 18817908  POINT (523610.424 177530.569)        457.0
#
#                                NAME   GSS_CODE  HECTARES  NONLD_AREA  \
# id
# 6524562   Blackwall and Cubitt Town  E05000575   296.713      72.369
# 21719580                 Manor Park  E05000488   133.487       0.000
# 18817908               Fulham Reach  E05000255    88.198       5.928
#
#           LB_GSS_CD                 BOROUGH   POLY_ID
# id
# 6524562   E09000030           Tower Hamlets  117258.0
# 21719580  E09000025                  Newham   51359.0
# 18817908  E09000013  Hammersmith and Fulham  117154.0

# %%
ax=gdf_wards[gdf_wards['NAME'].isnull()].plot()
wards.plot(ax=ax, edgecolor='r', facecolor='None', alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
#drop listings without ward name
#gdf_wards.drop(index=gdf[gdf_wards['NAME'].isnull()].index, axis=1, inplace=True)
print(gdf_wards.shape)
# Out:
# (67903, 19)

# %%
ax = gdf_wards.plot(column='NAME', markersize=0.5, alpha=0.5, figsize=(10,8))
wards.plot(ax=ax, edgecolor='r', facecolor='None', alpha=0.5);

# %%
ax = gdf_wards.plot(column="property_type",figsize=(12,8), marker='*', markersize=0.5)
ldn.plot(ax=ax, edgecolor='black', facecolor='black', alpha=0.5);\

# %% [markdown]
# ### listings per ward

# %%
gdf_wards.sample(3)
# Out:
#                                                        name  latitude  \
# id
# 35251859  Comfy, Bright and Lovely Room Near Train and B...  51.59500
# 23301778  Ideal 4BR with gorgeous garden in Highbury (Ve...  51.55965
# 39015989                   Premium studio in central London  51.51588
#
#           longitude                     property_type        room_type  price  \
# id
# 35251859   -0.25129  Private room in residential home     Private room   32.0
# 23301778   -0.09623           Entire residential home  Entire home/apt  303.0
# 39015989   -0.14988         Entire serviced apartment  Entire home/apt  140.0
#
#           availability_365  number_of_reviews_l30d first_review last_review  \
# id
# 35251859               365                       0   2019-06-02  2019-12-07
# 23301778                32                       0          NaN         NaN
# 39015989                 0                       0   2019-10-04  2019-10-04
#
#                                geometry  index_right                    NAME  \
# id
# 35251859  POINT (521226.177 189909.748)        191.0               Colindale
# 23301778  POINT (532068.354 186246.987)        537.0           Highbury East
# 39015989  POINT (528472.659 181284.138)        489.0  Marylebone High Street
#
#            GSS_CODE  HECTARES  NONLD_AREA  LB_GSS_CD      BOROUGH   POLY_ID
# id
# 35251859  E05000046   263.627         0.0  E09000003       Barnet   51066.0
# 23301778  E05000372   100.809         0.0  E09000019    Islington   50667.0
# 39015989  E05000641   100.107         0.0  E09000033  Westminster  117487.0

# %%
gdf_wards.reset_index(level=0, inplace=True)
gdf_wards.sample(3)
# Out:
#              id                                            name  latitude  \
# 41469  33423068       Willesden Green / Willesden Junction Flat  51.54416
# 39195  31434041  Large, 2 Bed, 2 Bath, Air-con, 24 Hr Reception  51.51660
# 26610  21728956   Cosy Double in London Ideal for 1 or a couple  51.52580
#
#        longitude                     property_type        room_type  price  \
# 41469   -0.24729                Entire rental unit  Entire home/apt   60.0
# 39195   -0.18281        Room in serviced apartment       Hotel room  496.0
# 26610   -0.13906  Private room in residential home     Private room   38.0
#
#        availability_365  number_of_reviews_l30d first_review last_review  \
# 41469                 0                       0   2019-08-11  2019-06-11
# 39195               308                       0   2019-06-29  2019-06-10
# 26610                 3                       6   2017-12-03  2021-06-16
#
#                             geometry  index_right            NAME   GSS_CODE  \
# 41469  POINT (521638.733 184262.663)        176.0       Harlesden  E05000091
# 39195  POINT (526185.899 181306.957)        479.0  Lancaster Gate  E05000638
# 26610  POINT (529195.323 182406.315)        515.0   Regent's Park  E05000142
#
#        HECTARES  NONLD_AREA  LB_GSS_CD      BOROUGH   POLY_ID
# 41469   111.370         0.0  E09000005        Brent  116952.0
# 39195    63.082         0.0  E09000033  Westminster   50773.0
# 26610   134.956         0.0  E09000007       Camden  117289.0

# %%
#create a dataframe with listings per London Ward
lw_total = gdf_wards.groupby(["GSS_CODE","BOROUGH"])["id"].count().sort_values()
lw_total
# Out:
# GSS_CODE   BOROUGH
# E05000157  Croydon                   1
# E05000067  Bexley                    2
# E05000404  Kingston upon Thames      2
# E05000211  Enfield                   4
# E05000309  Havering                  5
#                                   ...
# E05000589  Tower Hamlets           709
# E05000239  Hackney                 733
# E05000644  Westminster             742
# E05000638  Westminster             767
# E05000649  Westminster             955
# Name: id, Length: 625, dtype: int64

# %%
# locate specific value
#df.loc[df['col1'] == value]
# Out:
#                                                        name  latitude  \
# id
# 49573043  Sunny 2 bedrooms flat with parking, New Addington  51.34258
#
#           longitude       property_type        room_type  price  \
# id
# 49573043   -0.02051  Entire rental unit  Entire home/apt   49.0
#
#           availability_365  number_of_reviews_l30d first_review last_review  \
# id
# 49573043                31                       1   2021-05-24  2021-10-06
#
#                                geometry  index_right           NAME  \
# id
# 49573043  POINT (537969.274 162247.953)         29.0  New Addington
#
#            GSS_CODE  HECTARES  NONLD_AREA  LB_GSS_CD  BOROUGH  POLY_ID
# id
# 49573043  E05000157    241.71         0.0  E09000008  Croydon  50901.0

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(9, 14))

#sns.color_palette("mako", as_cmap=True)

ax = sns.countplot(y="BOROUGH", 
                   #hue="room_type",
                   data=gdf_wards,
                   order = gdf_wards['BOROUGH'].value_counts().index,
                   palette="mako")
plt.xlabel("Airbnb Listings per Borough", size=14)
plt.ylabel(None, size=14)


plt.savefig("Countplot_Listings_per_Borough.png", bbox_inches = 'tight')

# %%
# Create a sub frame for visualisations

cols_sub=['id', 'name', 'room_type',
       'price', 'availability_365', 'number_of_reviews_l30d', 'first_review',
       'last_review', 'geometry', 'NAME', 'GSS_CODE',
       'HECTARES', 'LB_GSS_CD', 'BOROUGH']

# %%
# create subframe with selected columns
gdf_total= gdf_wards[cols_sub]

#insert new columns

# count of listings per ward
gdf_total["list_count"]=gdf_total.groupby(["GSS_CODE"])["id"].transform("count")

#calculate density of listings per ward

gdf_total["list_density"]=gdf_total["list_count"]/gdf_total["HECTARES"]

gdf_total.head()
#print(f"Data frame is {gdf_total.shape[0]:,} x {gdf_total.shape[1]}")
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#       id                                               name        room_type  \
# 0  13913                Holiday London DB Room Let-on going     Private room
# 1  15400                Bright Chelsea  Apartment. Chelsea!  Entire home/apt
# 2  17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1  Entire home/apt
# 3  17506  Boutique Chelsea/Fulham Double bed 5-star ensuite     Private room
# 4  24328  Battersea bedroom & studio, parking, shared ga...  Entire home/apt
#
#    price  availability_365  number_of_reviews_l30d first_review last_review  \
# 0   65.0               339                       0   2011-07-11  2011-09-13
# 1   75.0                 2                       0   2012-07-16  2019-08-10
# 2  307.0               320                       0   2011-09-18  2019-11-02
# 3  150.0               364                       0          NaN         NaN
# 4  200.0               273                       0   2011-11-01  2015-10-24
#
#                         geometry                    NAME   GSS_CODE  HECTARES  \
# 0  POINT (530901.013 187213.787)              Tollington  E05000381    84.866
# 1  POINT (527284.576 178129.679)                 Stanley  E05000399    66.235
# 2  POINT (529075.790 181974.865)  Marylebone High Street  E05000641   100.107
# 3  POINT (525273.544 177139.513)                    Town  E05000264    65.129
# 4  POINT (527717.629 176292.280)               Latchmere  E05000617   108.326
#
#    LB_GSS_CD                 BOROUGH  list_count  list_density
# 0  E09000019               Islington       143.0      1.685009
# 1  E09000020  Kensington and Chelsea       209.0      3.155431
# 2  E09000033             Westminster       545.0      5.444175
# 3  E09000013  Hammersmith and Fulham       185.0      2.840517
# 4  E09000032              Wandsworth       196.0      1.809353

# %%
# check 
# locate specific value
gdf_total.loc[gdf_total["GSS_CODE"] == "E09000001"]
# Out:
#              id                                               name  \
# 119      137581                I Bedroom Apartment Tower of London
# 631      482178        Central London St. Paul's and City Location
# 1042     673067   4 minute walk to Tower Bridge, 2 bedrooms, wifi.
# 1246     847464                Luxury flat,Zone1,2bed/2bath/Lounge
# 1748    1439666                  Near Tower of London/Tower Bridge
# ...         ...                                                ...
# 67687  52615513  LUXURY LIVING - ELEGANT SPACIOUS 3-BED ON FLEE...
# 67689  52616026  FABULOUS 3-BEDROOM LUXURY APARTMENT IN THE CIT...
# 67733  52629282  City of London, double en-suite w. private par...
# 67734  52629585  Central London 2Bedroom Apartment Parking&Balcony
# 67737  52630462                      One Bedroom Apartment in City
#
#              room_type  price  availability_365  number_of_reviews_l30d  \
# 119    Entire home/apt  130.0                42                       0
# 631    Entire home/apt  120.0               276                       1
# 1042   Entire home/apt  179.0               126                       5
# 1246   Entire home/apt  220.0               138                       0
# 1748   Entire home/apt   95.0               248                       0
# ...                ...    ...               ...                     ...
# 67687  Entire home/apt  755.0               276                       0
# 67689  Entire home/apt  759.0               292                       1
# 67733     Private room  172.0                75                       0
# 67734  Entire home/apt  252.0                50                       0
# 67737  Entire home/apt  209.0               259                       0
#
#       first_review last_review                       geometry            NAME  \
# 119     2013-11-07  2019-08-10  POINT (533431.112 180867.762)  City of London
# 631     2012-07-31  2020-01-22  POINT (532063.079 181701.113)  City of London
# 1042    2012-10-24  2019-08-28  POINT (533753.921 181134.416)  City of London
# 1246    2014-03-04  2015-09-16  POINT (533339.343 180872.030)  City of London
# 1748    2015-05-06  2021-09-02  POINT (533685.859 180871.118)  City of London
# ...            ...         ...                            ...             ...
# 67687          NaN         NaN  POINT (531180.982 181421.211)  City of London
# 67689   2021-10-08  2021-10-08  POINT (531112.540 181490.662)  City of London
# 67733          NaN         NaN  POINT (532040.704 181600.381)  City of London
# 67734          NaN         NaN  POINT (532166.628 181510.181)  City of London
# 67737          NaN         NaN  POINT (533708.013 180847.219)  City of London
#
#         GSS_CODE  HECTARES  LB_GSS_CD         BOROUGH  list_count  \
# 119    E09000001   314.943  E09000001  City of London       356.0
# 631    E09000001   314.943  E09000001  City of London       356.0
# 1042   E09000001   314.943  E09000001  City of London       356.0
# 1246   E09000001   314.943  E09000001  City of London       356.0
# 1748   E09000001   314.943  E09000001  City of London       356.0
# ...          ...       ...        ...             ...         ...
# 67687  E09000001   314.943  E09000001  City of London       356.0
# 67689  E09000001   314.943  E09000001  City of London       356.0
# 67733  E09000001   314.943  E09000001  City of London       356.0
# 67734  E09000001   314.943  E09000001  City of London       356.0
# 67737  E09000001   314.943  E09000001  City of London       356.0
#
#        list_density
# 119        1.130363
# 631        1.130363
# 1042       1.130363
# 1246       1.130363
# 1748       1.130363
# ...             ...
# 67687      1.130363
# 67689      1.130363
# 67733      1.130363
# 67734      1.130363
# 67737      1.130363
#
# [356 rows x 16 columns]

# %%
#df.groupby(["item", "color"])["id"].count().reset_index(name="count")

# %%
#order=df.sort_values('Salary').Education)

# %%
# Need to work out the density per borough first!!!

sns.set_theme(style='darkgrid')
plt.figure(figsize=(9, 14))

ax = sns.barplot( x="list_density",
                  y="BOROUGH", 
                 #hue="room_type",
                  data=gdf_total,
                  order = gdf_total["BOROUGH"],
                  palette="mako")

plt.xlabel("Airbnb Listings Density per Borough", size=14)
plt.ylabel(None, size=14)


plt.savefig("Barplot_Listings_Density_per_Borough.png", bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2263/1795296012.py in <module>
#       2 plt.figure(figsize=(9, 14))
#       3
# ----> 4 ax = sns.barplot( x="list_density",
#       5                   y="BOROUGH",
#       6                  #hue="room_type",
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3180                           estimator, ci, n_boot, units, seed,
#    3181                           orient, color, palette, saturation,
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     204
#     205                 # Group the numeric data
# --> 206                 plot_data, value_label = self._group_longform(vals, groups,
#     207                                                               group_names)
#     208
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/seaborn/categorical.py in _group_longform(self, vals, grouper, order)
#     255         for g in order:
#     256             try:
# --> 257                 g_vals = grouped_vals.get_group(g)
#     258             except KeyError:
#     259                 g_vals = np.array([])
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in get_group(self, name, obj)
#     753             raise KeyError(name)
#     754
# --> 755         return obj._take_with_is_copy(inds, axis=self.axis)
#     756
#     757     @final
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/series.py in _take_with_is_copy(self, indices, axis)
#     905         See the docstring of `take` for full explanation of the parameters.
#     906         """
# --> 907         return self.take(indices=indices, axis=axis)
#     908
#     909     def _ixs(self, i: int, axis: int = 0):
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/series.py in take(self, indices, axis, is_copy, **kwargs)
#     891         indices = ensure_platform_int(indices)
#     892         new_index = self.index.take(indices)
# --> 893         new_values = self._values.take(indices)
#     894
#     895         result = self._constructor(new_values, index=new_index, fastpath=True)
#
# KeyboardInterrupt:

# %%
Ward_sum = gdf_total.groupby(["GSS_CODE","BOROUGH","HECTARES"])["id"].count().reset_index(name="count")
# sum up by ward


#calculate density of listings per ward

Ward_sum["density"]=Ward_sum["count"]/Ward_sum["HECTARES"]

Ward_sum.head()
# Out:
#     GSS_CODE               BOROUGH  HECTARES  count   density
# 0  E05000026  Barking and Dagenham   128.292     48  0.374146
# 1  E05000027  Barking and Dagenham   136.442     20  0.146582
# 2  E05000028  Barking and Dagenham   128.809     21  0.163032
# 3  E05000029  Barking and Dagenham   338.422     24  0.070917
# 4  E05000030  Barking and Dagenham   345.060     11  0.031879

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/algorithms.py in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    1782         try:
# -> 1783             sorter = values.argsort()
#    1784             ordered = values.take(sorter)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/arrays/base.py in argsort(self, ascending, kind, na_position, *args, **kwargs)
#     626
# --> 627         values = self._values_for_argsort()
#     628         return nargsort(
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/geopandas/array.py in _values_for_argsort(self)
#    1196         # Note: this is used in `ExtensionArray.argsort`.
# -> 1197         raise TypeError("geometries are not orderable")
#    1198
#
# TypeError: geometries are not orderable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2263/2954887524.py in <module>
#       2
#       3
# ----> 4 Ward_sum = gdf_total.groupby(["GSS_CODE","BOROUGH","HECTARES","geometry"])["id"].count().reset_index(name="count")
#       5
#       6
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/groupby/generic.py in count(self)
#     839             Count of values within each group.
#     840         """
# --> 841         ids, _, ngroups = self.grouper.group_info
#     842         val = self.obj._values
#     843
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/groupby/ops.py in group_info(self)
#     877     @cache_readonly
#     878     def group_info(self):
# --> 879         comp_ids, obs_group_ids = self._get_compressed_codes()
#     880
#     881         ngroups = len(obs_group_ids)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/groupby/ops.py in _get_compressed_codes(self)
#     897     def _get_compressed_codes(self) -> tuple[np.ndarray, np.ndarray]:
#     898         if len(self.groupings) > 1:
# --> 899             group_index = get_group_index(self.codes, self.shape, sort=True, xnull=True)
#     900             return compress_group_index(group_index, sort=self._sort)
#     901
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/groupby/ops.py in codes(self)
#     837     @property
#     838     def codes(self) -> list[np.ndarray]:
# --> 839         return [ping.codes for ping in self.groupings]
#     840
#     841     @property
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/groupby/ops.py in <listcomp>(.0)
#     837     @property
#     838     def codes(self) -> list[np.ndarray]:
# --> 839         return [ping.codes for ping in self.groupings]
#     840
#     841     @property
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/groupby/grouper.py in codes(self)
#     610             return self._codes
#     611
# --> 612         return self._codes_and_uniques[0]
#     613
#     614     @cache_readonly
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/groupby/grouper.py in _codes_and_uniques(self)
#     668             else:
#     669                 na_sentinel = -1
# --> 670             codes, uniques = algorithms.factorize(
#     671                 self.grouping_vector, sort=self._sort, na_sentinel=na_sentinel
#     672             )
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     763
#     764     if sort and len(uniques) > 0:
# --> 765         uniques, codes = safe_sort(
#     766             uniques, codes, na_sentinel=na_sentinel, assume_unique=True, verify=False
#     767         )
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/algorithms.py in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    1790                 ordered = _sort_tuples(values)
#    1791             else:
# -> 1792                 ordered = _sort_mixed(values)
#    1793
#    1794     # codes:
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/algorithms.py in _sort_mixed(values)
#    1842     """order ints before strings in 1d arrays, safe in py3"""
#    1843     str_pos = np.array([isinstance(x, str) for x in values], dtype=bool)
# -> 1844     nums = np.sort(values[~str_pos])
#    1845     strs = np.sort(values[str_pos])
#    1846     return np.concatenate([nums, np.asarray(strs, dtype=object)])
#
# <__array_function__ internals> in sort(*args, **kwargs)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/numpy/core/fromnumeric.py in sort(a, axis, kind, order)
#     996     else:
#     997         a = asanyarray(a).copy(order="K")
# --> 998     a.sort(axis=axis, kind=kind, order=order)
#     999     return a
#    1000
#
# TypeError: '<' not supported between instances of 'Point' and 'Point'

# %%
# basic map 

gdf_total.plot(column='list_density', cmap='plasma', 
         scheme='FisherJenks', k=7, edgecolor='None', legend=True, figsize=(9,7));

# %%
# basic map 

gdf_total.plot()
# Out:
# <AxesSubplot:>

# %%
test = gpd.sjoin(gdf, wards, how='right', op='within')
test.head()
# Out:
#    index_left                                               name  latitude  \
# 0    37542338   Spacious garden cabin, peaceful setting & homely  51.35796
# 0    29327089                                Greater London Flat  51.35857
# 0    51402829  3 bedroom flat with 4k TVs, Sky/Netflix & Parking  51.36000
# 0    49745609              Quite & Peaceful House in Chessington  51.36002
# 0    42982046    Beautiful 3 Bedroom House in Chessington Surrey  51.36004
#
#    longitude                property_type        room_type  price  \
# 0   -0.28989        Private room in cabin     Private room   55.0
# 0   -0.30121  Private room in rental unit     Private room   80.0
# 0   -0.29442   Entire condominium (condo)  Entire home/apt  131.0
# 0   -0.28950      Entire residential home  Entire home/apt  130.0
# 0   -0.28792      Entire residential home  Entire home/apt  149.0
#
#    availability_365  number_of_reviews_l30d first_review last_review  \
# 0                25                       2   2019-10-05  2021-10-04
# 0               173                       0          NaN         NaN
# 0                75                       2   2021-09-17  2021-09-27
# 0               226                       0          NaN         NaN
# 0               353                       1   2020-05-31  2021-09-18
#
#                 NAME   GSS_CODE  HECTARES  NONLD_AREA  LB_GSS_CD  \
# 0  Chessington South  E05000405   755.173         0.0  E09000021
# 0  Chessington South  E05000405   755.173         0.0  E09000021
# 0  Chessington South  E05000405   755.173         0.0  E09000021
# 0  Chessington South  E05000405   755.173         0.0  E09000021
# 0  Chessington South  E05000405   755.173         0.0  E09000021
#
#                 BOROUGH  POLY_ID  \
# 0  Kingston upon Thames    50840
# 0  Kingston upon Thames    50840
# 0  Kingston upon Thames    50840
# 0  Kingston upon Thames    50840
# 0  Kingston upon Thames    50840
#
#                                             geometry
# 0  POLYGON ((516401.600 160201.800, 516407.300 16...
# 0  POLYGON ((516401.600 160201.800, 516407.300 16...
# 0  POLYGON ((516401.600 160201.800, 516407.300 16...
# 0  POLYGON ((516401.600 160201.800, 516407.300 16...
# 0  POLYGON ((516401.600 160201.800, 516407.300 16...

# %%
cols_sub=['index_left','name',
 'room_type',
 'price',
 'availability_365',
 'number_of_reviews_l30d',
 'first_review',
 'last_review',
 'geometry',
 'NAME',
 'GSS_CODE',
 'HECTARES',
 'LB_GSS_CD',
 'BOROUGH']

# %%
# create subframe with selected columns
wards_total= test[cols_sub]

# %%
#insert new columns

# count of listings per ward
wards_total["list_count"]=wards_total.groupby(["GSS_CODE"])["index_left"].transform("count")
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
#calculate density of listings per ward

wards_total["list_density"]=wards_total["list_count"]/wards_total["HECTARES"]

wards_total.head()
#print(f"Data frame is {gdf_total.shape[0]:,} x {gdf_total.shape[1]}")
# Out:
#    index_left                                               name  \
# 0    37542338   Spacious garden cabin, peaceful setting & homely
# 0    29327089                                Greater London Flat
# 0    51402829  3 bedroom flat with 4k TVs, Sky/Netflix & Parking
# 0    49745609              Quite & Peaceful House in Chessington
# 0    42982046    Beautiful 3 Bedroom House in Chessington Surrey
#
#          room_type  price  availability_365  number_of_reviews_l30d  \
# 0     Private room   55.0                25                       2
# 0     Private room   80.0               173                       0
# 0  Entire home/apt  131.0                75                       2
# 0  Entire home/apt  130.0               226                       0
# 0  Entire home/apt  149.0               353                       1
#
#   first_review last_review                                           geometry  \
# 0   2019-10-05  2021-10-04  POLYGON ((516401.600 160201.800, 516407.300 16...
# 0          NaN         NaN  POLYGON ((516401.600 160201.800, 516407.300 16...
# 0   2021-09-17  2021-09-27  POLYGON ((516401.600 160201.800, 516407.300 16...
# 0          NaN         NaN  POLYGON ((516401.600 160201.800, 516407.300 16...
# 0   2020-05-31  2021-09-18  POLYGON ((516401.600 160201.800, 516407.300 16...
#
#                 NAME   GSS_CODE  HECTARES  LB_GSS_CD               BOROUGH  \
# 0  Chessington South  E05000405   755.173  E09000021  Kingston upon Thames
# 0  Chessington South  E05000405   755.173  E09000021  Kingston upon Thames
# 0  Chessington South  E05000405   755.173  E09000021  Kingston upon Thames
# 0  Chessington South  E05000405   755.173  E09000021  Kingston upon Thames
# 0  Chessington South  E05000405   755.173  E09000021  Kingston upon Thames
#
#    list_count  list_density
# 0          15      0.019863
# 0          15      0.019863
# 0          15      0.019863
# 0          15      0.019863
# 0          15      0.019863

# %%
sns.set_style('whitegrid')
#ax = wards_total.plot(facecolor=(0.8, 0.8, 0.8, 0.5), edgecolor='gray', linewidth=0.25, figsize=(10,10))
#gdf_total.plot(ax=ax, column='list_density', cmap='viridis', edgecolor='none', legend=True);


# basic map 

wards_total.plot(column='list_density', cmap='plasma', 
         scheme='FisherJenks', k=7, edgecolor='white', legend=True, figsize=(9,7));

# %%
sns.set_style('whitegrid')

wards_total.plot(column='list_density', cmap='plasma', 
         scheme='FisherJenks', k=3, edgecolor='white',linewidth=0.5, legend=True, figsize=(9,7));

# %%
wards_total['list_density'].plot.hist() # histogram
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
wards_total["ln_list_density"]= np.log(wards_total["list_density"])
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
wards_total['ln_list_density'].plot.hist() # histogram
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
gdf_wards.plot.hexbin(x='longitude', y='latitude', gridsize=80
            
               , figsize=(15,10))  #hex bin plot
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
import pysal as ps
# https://github.com/pysal/mapclassify
import mapclassify as mc
# https://jiffyclub.github.io/palettable/
import palettable.matplotlib as palmpl
from legendgram import legendgram

f,ax = plt.subplots(figsize=(10,8))
gdf.plot(column='price', scheme='Quantiles', cmap='magma', k=5, ax=ax)
q = mc.Quantiles(gdf.price.values, k=5)

# https://github.com/pysal/legendgram/blob/master/legendgram/legendgram.py
legendgram(f, ax, 
               gdf.price, q.bins, pal=palmpl.Magma_5,
               legend_size=(.4,.2), # legend size in fractions of the axis
               loc = 'upper left', # mpl-style legend loc
               clip = (0,500), # clip range of the histogram
               frameon=True)
# Out:
# <Axes:>

# %% [markdown]
# # Executive Briefing
#
# This should be composed of markdown cells _only_. You may have more than one markdown cell so as to support a useful Table of Contents. Images should be included by reference using the standard Markdown format `![Alt text here](local/image/created_in_code.png)`.
# <br>
# Add each section of your briefing to the corresponding cell below.
# <br>
# _Additional guidence on the structure can be found on Moodle_

# %% [markdown]
# ## Executive summary

# %% [markdown]
# ## Background

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ## Conclusion

# %% [markdown]
# # Bibliography
#
# This should be a list in markdown of any documents referenced in the _Executive Briefing_. Please also link to the document using the standard Markdown format `[Link text](https://link.website.org/)`. If the document is an academic article or other piece requiring authentication please link to a DOI.

# %%
#add columns 
lw_total = gdf_wards.groupby(["GSS_CODE","BOROUGH"])["id"].count().sort_values()
lw_total
